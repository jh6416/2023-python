# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
titanic = pd.read_csv("data/titanic.csv", low_memory=False)

# %%
titanic["age"]=titanic["age"].replace(["?"],[None]).astype("float")
titanic["fare"]=titanic["fare"].replace(["?"],[None]).astype("float")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df = titanic.groupby(["pclass","sex"]).mean()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10084\1721735714.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = titanic.groupby(["pclass","sex"]).mean()

# %%
df.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
pops=pd.read_csv("data/state_pops.csv")

# %%
pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.set_index("state")
# Out:
#        year   population
# state
# AL     2012    4817528.0
# AL     2010    4785570.0
# AL     2011    4801627.0
# AL     2009    4757938.0
# AL     2013    4833722.0
# ...     ...          ...
# USA    2013  316128839.0
# USA    2009  306771529.0
# USA    2010  309326295.0
# USA    2011  311582564.0
# USA    2012  313873685.0
#
# [1272 rows x 2 columns]

# %%
pops.set_index("year")
# Out:
#      state   population
# year
# 2012    AL    4817528.0
# 2010    AL    4785570.0
# 2011    AL    4801627.0
# 2009    AL    4757938.0
# 2013    AL    4833722.0
# ...    ...          ...
# 2013   USA  316128839.0
# 2009   USA  306771529.0
# 2010   USA  309326295.0
# 2011   USA  311582564.0
# 2012   USA  313873685.0
#
# [1272 rows x 2 columns]

# %%
pops.set_index(["state","year"])
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(["state","year"]).sort_index(ascending=True)
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(["state","year"], inplace=True)

# %% [markdown]
# inplace = True 는 데이터 원본을 인덱스가 적용된 형태로 고정시키는 효과가 있다.
# 그러나 inplace = True 가 없으면 index를 적용하여 나온 내용이 한 번 출력되기만 하고 원본
# 데이터에 영향을 주지는 못한다.

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(ascending=False)
# Out:
#             population
# state year
# WY    2013    582658.0
#       2012    576626.0
#       2011    567329.0
#       2010    564222.0
#       2009    559851.0
# ...                ...
# AK    1994    603308.0
#       1993    599434.0
#       1992    588736.0
#       1991    570193.0
#       1990    553290.0
#
# [1272 rows x 1 columns]

# %%
plt.style.use("ggplot")

# %%
kor_s = [
    1427.22,
    1192.57,
    993.93,
    965.23,
    1130.65,
    1207.23,
    1310.46,
    1477.18,
    1220.04,
    948.05,
    1139.97,
    1267.64,
    1379.61,
    1643.80,
    1931.38,
    2061.07,
    2094.65,
    2449.08,
    2746.21,
    2913.36,
    3217.86,
    4246.11
]

us_s = [
    3783.67,
    2029.61,
    1539.73,
    1647.17,
    1986.53,
    2099.32,
    2263.41,
    2578.47,
    2161.68,
    1845.39,
    2349.89,
    2677.44,
    2965.74,
    3541.29,
    4375.10,
    4945.55,
    4987.79,
    6235.30,
    7425.96,
    7940.36,
    10201.51,
    14294.87
]

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

plt.figure(figsize=(10,4))
plt.rc("font", family = "Gulim")
plt.subplot(1,2,1)
plt.plot(years, us_s, color = "b", label="미국 주가")
plt.plot(years, kor_s, color="r", label="한국 주가")
plt.title("주가 변동 선 그래프")
plt.xlabel("Year")
plt.legend()
plt.subplot(1,2,2)
plt.bar(years, us_s, bottom=kor_s, color = "b", label="미국 주가")
plt.bar(years, kor_s, color="r", label="한국 주가")
plt.title("주가 변동 막대 그래프")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(["state","year"]).sort_index(level=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pops.set_index(["state","year"]).sort_index(level=1)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
# ...

# %%
pops.set_index(["state","year"]).sort_index(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pops.set_index(["state","year"]).sort_index(ascending=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# ...

# %%
pops.sort_index(level=[1], ascending=[False])
# Out:
#              population
# state year
# AL    2013    4833722.0
# AK    2013     735132.0
# AZ    2013    6626624.0
# AR    2013    2959373.0
# CA    2013   38332521.0
# ...                 ...
# WV    1990    1792548.0
# WI    1990    4904562.0
# WY    1990     453690.0
# PR    1990          NaN
# USA   1990  249622814.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[0,1], ascending=[False,True])

# %%
pops.sort_index(level=[0], ascending=[False])

# %%
pops.set_index(["state","year"], inplace = True).sort_index(ascending=True)

# %%
pops.sort_index()

# %%
pops.sort_index().loc["CA"]

# %%
pops.loc[["CA","AK"]]

# %%
pops.sort_index()

# %%
pops.sort_index().loc["NM":"TX"]
# Out:
#             population
# state year
# NM    1990   1521574.0
#       1991   1555305.0
#       1992   1595442.0
#       1993   1636453.0
#       1994   1682398.0
# ...                ...
# TX    2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
#       2013  26448193.0
#
# [312 rows x 1 columns]

# %%
pops.sort_index().loc["MT",1992]
# Out:
# population    825770.0
# Name: (MT, 1992), dtype: float64

# %%
pops.sort_index().loc[["AK"]][2:6]
# Out:
#             population
# state year
# AK    1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.sort_index().loc[("AK",1992):("AK",1995)]
# Out:
#             population
# state year
# AK    1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.sort_index().loc[("AK",2011):("AL",1993)]
# Out:
#             population
# state year
# AK    2011    723375.0
#       2012    730307.0
#       2013    735132.0
# AL    1990   4050055.0
#       1991   4099156.0
#       1992   4154014.0
#       1993   4214202.0

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.set_index("name").loc["Beattie, Mr. Thomson"]
# Out:
# pclass                  1
# survived                0
# sex                  male
# age                  36.0
# sibsp                   0
# parch                   0
# ticket              13050
# fare              75.2417
# cabin                  C6
# embarked                C
# boat                    A
# body                    ?
# home.dest    Winnipeg, MN
# Name: Beattie, Mr. Thomson, dtype: object

# %%
titanic["name"].loc[19]
# Out:
# 'Beattie, Mr. Thomson'

# %%
titanic.loc[19]["name"]
# Out:
# 'Beattie, Mr. Thomson'

# %%
titanic.loc[(19, "name")]
# Out:
# 'Beattie, Mr. Thomson'

# %%
pops["population"]=pops["population"].replace([""],[None]).astype("float")

# %%
pops.set_index(["year","state"]).sort_index().loc[1990]
# Out:
#         population
# state
# AK        553290.0
# AL       4050055.0
# AR       2356586.0
# AZ       3684097.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DC        605321.0
# DE        669567.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# IA       2781018.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# MA       6022639.0
# MD       4799770.0
# ME       1231719.0
# MI       9311319.0
# MN       4389857.0
# MO       5128880.0
# MS       2578897.0
# MT        800204.0
# NC       6664016.0
# ND        637685.0
# NE       1581660.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NV       1220695.0
# NY      18020784.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# PR             NaN
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# USA    249622814.0
# ...
