# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# 위 명령어는 matplotlib이 현재 주피터노트북에서 실행될 수 있도록 한다.

# %%
x= np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
c=x**3
c
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y,"#2ae2e2")
plt.xlabel("X Axis Title Here")
plt.ylabel("Y Axis Title Here")
plt.title("String Title Here")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# plt matplotlib 을 저장했고, matplotlib에 있는 plot이라는 메소드를 통해 어떤 상관관계가 있는 그래프를 그릴 것인지를 지정하고, 해당 그래프의 색깔을 지정한다.
#
# plot x축에 대입할 값, y축에 대입할 값, "라인 컬러"
#
# plot : 이야기

# %%
plt.plot(y,x,"g")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("String Title Here")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %% [markdown]
# Subplot (1,2,1)의 의미는, 기존 plot을 1을 기준으로 가로에 두개의 그래프를 넣는다는 의미이고, 그 다음 1은 두개의 그래프 위치 중 첫번째에 plt.plot(x, y, 'r--')  라는 그래프를 넣는다는 의미이다

# %%
plt.subplot(2,3,1)
plt.plot(x,y,"r--")
plt.subplot(2,3,3)
plt.plot(y,x,'g*-')

# %%
plt.subplot(2,3,2)
plt.plot(x,y,"r--")
plt.subplot(1,3,1)
plt.plot(y,x,'g*-')

# %% [markdown]
# plt.subplot(1,3,1) 은 기존 plot의 범위에 3개의 그래프를 넣는다는 의미이고, 그 그래프 위치 3가지 중 첫번째에 plt.plot(x,y,'r--')그래프를 넣는다는 뜻이다.

# %%
plt.subplot(1,4,1)
plt.plot(x,y,'y--')
plt.subplot(1,4,3)
plt.plot(y,x,'b*-')

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.3,0.9])

axes.plot(x,y,"b")
axes.set_xlabel("Set X Label")
axes.set_ylabel("Set Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %% [markdown]
# Figure라는 메소드는 그래프의 크기와 가로 세로 비율을 정할 수 있도록 해준다.
#
# axes : 축
#
# fig.add_axes([왼쪽축에서의 거리, 바닥에서의 거리, 그래프의 폭, 그래프의 높이])
#
# 위 add_axes 안에 들어갈 수 있는 숫자의 범위는 0부터 1까지 가능

# %%
fig.add_axes
# Out:
# <bound method FigureBase.add_axes of <Figure size 640x480 with 1 Axes>>

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8]) # 정사각형
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) # 가로가 넓은 직사각형
axes.plot(x,y,"b")
axes.set_xlabel("X Label_axes2")
axes.set_ylabel("Y Label_axes2")
axes.set_title("Axes 2 Title")
axes2.plot(y,x,"r")
axes2.set_xlabel("X Label_axes2")
axes2.set_ylabel("Y Label_axes2")
axes2.set_title("Axes 2 Title")
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
fig = plt.figure()


axes = fig.add_axes([0.1,0.1,0.8,0.7]) # 정사각형
axes.plot(x,y,"#fb6544")
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Title")
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
for ax in axes:
    ax.plot(x,y,"b")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title("Title")
fig

# %%
a=np.linspace(0,5,11)
a
b=a

# %%
c = np.linspace(0,125,5)
c
# Out:
# array([  0.  ,  31.25,  62.5 ,  93.75, 125.  ])

# %%
# x= 5x5 y= 5x25 z=5x125
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.1,0.8]) # 정사각형
axes2 = fig.add_axes([0.1,0.1,0.1,0.8])
axes.plot(x,y,"#fb6544",120)
axes.set_xlabel("X Label_axes2")
axes.set_ylabel("Y Label_axes2")
axes.set_title("Axes 2 Title")
axes2.plot(a,b,"#fb6544",120)
axes2.set_xlabel("X Label_axes2")
axes2.set_ylabel("Y Label_axes2")
axes2.set_title("Axes 2 Title")
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
fig = plt.figure()


axes = fig.add_axes([0,0,0.1,1]) # 정사각형
axes.plot(x,y,"#fb6544",120)
axes.plot(x,b,"c")
axes.plot(x,c,"g")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.1,1])
ax.plot(x,x,"c")
ax.plot(x,x**2,"r")
ax.plot(x,x**3,"g")

# %%
fig = plt.figure()
ax = fig.add_axes([0.5,0.5,1,1])
ax.plot(x,x**2,"b.-")
ax.plot(x,x**3,"g--")

# %%
fig = plt.figure()

fig, ax = plt.subplots()
ax.plot(x,x**2,"b.-")
ax.plot(x,x**3,"g--")

# %%
fig = plt.figure()

fig, ax = plt.subplots()

ax.plot(x,x+1,"#00FF7F")
ax.plot(x,x+2,"blueviolet")
ax.plot(x,x+3,"#FF69B4")

# %%
fig = plt.figure()

ax = fig.add_axes([0.1,0.1,1,0.7])

ax.plot(x,x+1,"#F08080",linewidth=0.5)
ax.plot(x,x+2,"#EEE8AA",linewidth=0.8)
ax.plot(x,x+3,"#1E90FF",linewidth=1)
ax.plot(x,x+4,"silver",linewidth=2)

# %% [markdown]
# figsize = 가로x세로
#
# fig, ax = plt.subplots(figsize=(12,6))
#
# ax.plot(x,x+1,color="red", linewidth = "0.25")
#
# ax.plot(x,x+2,color="red", linewidth = "0.50")
#
# ax.plot(x,x+3,color="red", lw = "1.00")
#
# ax.plot(x,x+4,color="red", lw = "2.00")

# %%
fig = plt.figure()

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color="#DB7093", linewidth = "0.25")
ax.plot(x,x+2,color="#F8F8FF", linewidth = "0.50")
ax.plot(x,x+3,color="#E6E6FA", lw = "1.00",linestyle='-')
ax.plot(x,x+4,"#778899", lw = "2.00")
ax.plot(x,x+5,"r-.", lw = "2.00")
ax.plot(x,x+6,"r:", lw = "2.00")

# %%
fig = plt.figure()

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color="#DB7093", linewidth = "0.25")
ax.plot(x,x+2,color="#F8F8FF", linewidth = "0.50")
ax.plot(x,x+3,color="#E6E6FA", lw = "1.00",linestyle='-')
ax.plot(x,x+4,"#778899", lw = "3")
ax.plot(x,x+5,"darkblue", lw = "3", ls="-.")
ax.plot(x,x+6,"r:", lw = "3")

# %%
fig = plt.figure()

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color="#DB7093", linewidth = "0.25")
ax.plot(x,x+2,color="#F8F8FF", linewidth = "0.50")
ax.plot(x,x+3,color="#E6E6FA", lw = "1.00",linestyle='-')
ax.plot(x,x+4,"#778899", lw = "3")
ax.plot(x,x+5,"darkblue", lw = "3", ls="-")
ax.plot(x,x+6,"r", lw = "3",ls="-.")
ax.plot(x,x+7,color="#ff3212", linewidth = "3", ls = ":")

ax.plot(x,x+9,"b", lw = "3", ls='-', marker='+')
ax.plot(x,x+10,"b", lw = "3", ls='--',marker='o')
ax.plot(x,x+11,"b", lw = "3",ls='-',marker="s")
ax.plot(x,x+12,color="b", linewidth = "3", ls="--", marker='1')

# %%
m = np.array([5500,6500,7200,9000,11500,15000])
y = np.array([20,25,30,32,40,45])

# %%
fig = plt.figure()

fig, ax = plt.subplots()
ax.set_xlabel("age")
ax.set_ylabel("salary")
ax.set_title("My Future Salary")
ax.plot(y,m,"c")

# %%
nums = np.arange(5)
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums,nums**3)
plt.xlabel("time")
plt.ylabel("development")
plt.title("My development speed")
# Out:
# Text(0.5, 1.0, 'My development speed')

# %%
nums = np.arange(5)
plt.plot(nums,nums, label = "Music")
plt.plot(nums, nums*nums, label = "Math")
plt.plot(nums,nums**3, label = "Coding")
plt.xlabel("time")
plt.ylabel("development")
plt.title("My development speed")
plt.legend()
